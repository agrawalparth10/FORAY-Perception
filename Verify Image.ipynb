# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
file = open('image.txt',mode='r')

# %%
text = []
for line in file:
    text.append(line)

# %%
def convert(text):
    image = []
    for i in range(len(text)):
        new_text = text[i].replace("  ",",")
        next_text = new_text.split(",")
        num = []
        for n in next_text:
            num.append(int(n))
        image.append(num)
    return np.array(image)

# %%
image_arr = convert(test)

# %%
print(image_arr.shape)
# Out:
# (160, 120)

# %%
plt.imshow(image_arr,cmap='gray')
